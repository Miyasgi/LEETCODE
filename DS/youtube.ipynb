# %%
import youtube_transcript_api
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript(video_id='ZLH6mB-hrHA')
# Out:
# [{'text': '[Music]', 'start': 4.9, 'duration': 11.34},
#  {'text': '[Music]', 'start': 18.82, 'duration': 3.05},
#  {'text': 'so', 'start': 36.719, 'duration': 3.0},
#  {'text': '[Music]', 'start': 58.13, 'duration': 3.25},
#  {'text': '[Music]', 'start': 72.34, 'duration': 4.969},
#  {'text': 'i almost got killed', 'start': 80.72, 'duration': 3.759},
#  {'text': 'good morning everyone this is john with',
#   'start': 82.32,
#   'duration': 3.92},
#  {'text': "gun deals and today we're going to be",
#   'start': 84.479,
#   'duration': 3.761},
#  {'text': 'talking about the', 'start': 86.24, 'duration': 6.16},
#  {'text': 'very prolific glock 17 gen 3. but before',
#   'start': 88.24,
#   'duration': 6.08},
#  {'text': "we get into that if you don't know gun",
#   'start': 92.4,
#   'duration': 4.079},
#  {'text': 'deals is a website that provides you',
#   'start': 94.32,
#   'duration': 4.56},
#  {'text': 'with links to some of the best prices',
#   'start': 96.479,
# ...
